# %% [markdown]
# # Tic-tac-toe Multiplayer
#
# #### (Using NumPy)
#
# ###### Srikar R

# %% [markdown]
# This tic-tac-toe is a multiplayer game made using NumPy.It is quite simple in code and its rules. The game is just like the regular tic-tac-toe with 'x' and 'o's. The board is displayed below and you must enter any number from 1 to 9 to enter your respected character (x or o).
#
# #### The below image might help you out to find the position:
#
#
# $$\begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ 7 & 8 & 9 \end{bmatrix}$$
#
# ### Note!
#
# You must be fair to your opponent and play it like you play it on paper. You cannot change your opponent's character to suit yours.
#
# Since the computer cannot decide who won, you must type any letter other than a number in order to finish the game or resign or quit the game. The command will result an error which means that the game has ended. Dont forget to refresh the board!
#
# ###### In order to refresh the board, just run the below command or the command at the end.

# %%
board=np.array([[_,_,_],[_,_,_],[_,_,_]])
print(board)
# Out:
# [['' '' '']
#  ['' '' '']
#  ['' '' '']]

# %% [markdown]
# ## Run this command to begin the system

# %%
def start():
    import numpy as np
    player_1=(input("Enter player 1 name: "))
    player_2=(input("Enter player 2 name: "))
    print()
    print("Player 1 is always x and player 2 is always o")
    print()
    
    one=int(input("Enter x at any postion,player 1: "))
    if one==1:
        board[0,0]='x'
    elif one==2:
        board[0,1]='x'
    elif one==3:
        board[0,2]='x'
    elif one==4:
        board[1,0]='x'
    elif one==5:
        board[1,1]='x'
    elif one==6:
        board[1,2]='x'
    elif one==7:
        board[2,0]='x'
    elif one==8:
        board[2,1]='x'
    elif one==9:
        board[2,2]='x'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    two=int(input("Enter o at any postion,player 2: "))
    if two==1:
        board[0,0]='o'
    elif two==2:
        board[0,1]='o'
    elif two==3:
        board[0,2]='o'
    elif two==4:
        board[1,0]='o'
    elif two==5:
        board[1,1]='o'
    elif two==6:
        board[1,2]='o'
    elif two==7:
        board[2,0]='o'
    elif two==8:
        board[2,1]='o'
    elif two==9:
        board[2,2]='o'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    one=int(input("Enter x at any postion,player 1: "))
    if one==1:
        board[0,0]='x'
    elif one==2:
        board[0,1]='x'
    elif one==3:
        board[0,2]='x'
    elif one==4:
        board[1,0]='x'
    elif one==5:
        board[1,1]='x'
    elif one==6:
        board[1,2]='x'
    elif one==7:
        board[2,0]='x'
    elif one==8:
        board[2,1]='x'
    elif one==9:
        board[2,2]='x'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    two=int(input("Enter o at any postion,player 2: "))
    if two==1:
        board[0,0]='o'
    elif two==2:
        board[0,1]='o'
    elif two==3:
        board[0,2]='o'
    elif two==4:
        board[1,0]='o'
    elif two==5:
        board[1,1]='o'
    elif two==6:
        board[1,2]='o'
    elif two==7:
        board[2,0]='o'
    elif two==8:
        board[2,1]='o'
    elif two==9:
        board[2,2]='o'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    one=int(input("Enter x at any postion,player 1: "))
    if one==1:
        board[0,0]='x'
    elif one==2:
        board[0,1]='x'
    elif one==3:
        board[0,2]='x'
    elif one==4:
        board[1,0]='x'
    elif one==5:
        board[1,1]='x'
    elif one==6:
        board[1,2]='x'
    elif one==7:
        board[2,0]='x'
    elif one==8:
        board[2,1]='x'
    elif one==9:
        board[2,2]='x'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    two=int(input("Enter o at any postion,player 2: "))
    if two==1:
        board[0,0]='o'
    elif two==2:
        board[0,1]='o'
    elif two==3:
        board[0,2]='o'
    elif two==4:
        board[1,0]='o'
    elif two==5:
        board[1,1]='o'
    elif two==6:
        board[1,2]='o'
    elif two==7:
        board[2,0]='o'
    elif two==8:
        board[2,1]='o'
    elif two==9:
        board[2,2]='o'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    one=int(input("Enter x at any postion,player 1: "))
    if one==1:
        board[0,0]='x'
    elif one==2:
        board[0,1]='x'
    elif one==3:
        board[0,2]='x'
    elif one==4:
        board[1,0]='x'
    elif one==5:
        board[1,1]='x'
    elif one==6:
        board[1,2]='x'
    elif one==7:
        board[2,0]='x'
    elif one==8:
        board[2,1]='x'
    elif one==9:
        board[2,2]='x'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    two=int(input("Enter o at any postion,player 2: "))
    if two==1:
        board[0,0]='o'
    elif two==2:
        board[0,1]='o'
    elif two==3:
        board[0,2]='o'
    elif two==4:
        board[1,0]='o'
    elif two==5:
        board[1,1]='o'
    elif two==6:
        board[1,2]='o'
    elif two==7:
        board[2,0]='o'
    elif two==8:
        board[2,1]='o'
    elif two==9:
        board[2,2]='o'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    one=int(input("Enter x at any postion,player 1: "))
    if one==1:
        board[0,0]='x'
    elif one==2:
        board[0,1]='x'
    elif one==3:
        board[0,2]='x'
    elif one==4:
        board[1,0]='x'
    elif one==5:
        board[1,1]='x'
    elif one==6:
        board[1,2]='x'
    elif one==7:
        board[2,0]='x'
    elif one==8:
        board[2,1]='x'
    elif one==9:
        board[2,2]='x'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    two=int(input("Enter o at any postion,player 2: "))
    if two==1:
        board[0,0]='o'
    elif two==2:
        board[0,1]='o'
    elif two==3:
        board[0,2]='o'
    elif two==4:
        board[1,0]='o'
    elif two==5:
        board[1,1]='o'
    elif two==6:
        board[1,2]='o'
    elif two==7:
        board[2,0]='o'
    elif two==8:
        board[2,1]='o'
    elif two==9:
        board[2,2]='o'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    one=int(input("Enter x at any postion,player 1: "))
    if one==1:
        board[0,0]='x'
    elif one==2:
        board[0,1]='x'
    elif one==3:
        board[0,2]='x'
    elif one==4:
        board[1,0]='x'
    elif one==5:
        board[1,1]='x'
    elif one==6:
        board[1,2]='x'
    elif one==7:
        board[2,0]='x'
    elif one==8:
        board[2,1]='x'
    elif one==9:
        board[2,2]='x'
    else:
        print("Enter a number from 1 to 9")
    print(board)
    two=int(input("Enter o at any postion,player 2: "))
    if two==1:
        board[0,0]='o'
    elif two==2:
        board[0,1]='o'
    elif two==3:
        board[0,2]='o'
    elif two==4:
        board[1,0]='o'
    elif two==5:
        board[1,1]='o'
    elif two==6:
        board[1,2]='o'
    elif two==7:
        board[2,0]='o'
    elif two==8:
        board[2,1]='o'
    elif two==9:
        board[2,2]='o'
    else:
        print("Enter a number from 1 to 9")
    print(board)

# %% [markdown]
# # Type 'start()' in a line to start the game!

# %%
start()
# Out:
# Enter player 1 name: h
# Enter player 2 name: j
#
# Player 1 is always x and player 2 is always o
#
# Enter x at any postion,player 1: dfgh
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-85ba4973bfbb> in <module>
# ----> 1 start()
#
# <ipython-input-56-4cb0ee0d1887> in start()
#       7     print()
#       8
# ----> 9     one=int(input("Enter x at any postion,player 1: "))
#      10     if one==1:
#      11         board[0,0]='x'
#
# ValueError: invalid literal for int() with base 10: 'dfgh'

# %% [markdown]
# ### Run the below command to refresh the board and type 'start()' in a new command to start a new game!

# %%
board=np.array([[_,_,_],[_,_,_],[_,_,_]])
